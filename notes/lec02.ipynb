# %% [markdown]
# <img src="../files/misc/logo.gif" width=300/>
# <h1 style="color:#872325">List & Tuples</h1>

# %%
# Booleanos
print(True)
print(type(True))
print(False)
print(type(False))
# Out:
# True
# <class 'bool'>
# False
# <class 'bool'>

# %% [markdown]
# ## [Lists]
# Una lista es un arreglo *ordenado* de elementos. Se define por valores separados por coma y encerrados por dos corchetes (`[]`)

# %%
# Como inicializamos o creamos una lista
mi_lista = []
otra_lista = list()

print(mi_lista)
print(otra_lista)
# Out:
# []
# []

# %%
materias = ["CALCULO", "PROBABILIDAD", "ESTADISTICA", "PROGRAMACION"]
print(type(materias))
# Out:
# <class 'list'>

# %% [markdown]
# ### Subsetting:
# En una lista, al igual que con string (una sequencia ordenada de carácteres), accedemos a los valores de una lista usando la misma notación de corchetes.

# %%
# Seleccionamos el primer elemento
materias[0]

# Seleccionamos el ultimo elemento
materias[-1]

# Podemos seleccionar intervalos
materias[0:2]
# Out:
# ['CALCULO', 'PROBABILIDAD']

# %%
print("Numero de elementos en la lista: ", len(materias))
# Out:
# Numero de elementos en la lista:  4

# %% [markdown]
# <h2 style="color:#d62728">Ejercicios</h2>
# Dada la lista de materias
#
# 1. Accede al primer elemento de la lista
# 2. Accede al tercer elmento de la lista
# 3. Accede al último elmento dentro de la lista
# 4. Accede del segundo al cuarto elemento de la lista
# 5. Accede al último carácter del primer elemento

# %%
materias[0]
# Out:
# 'CALCULO'

# %%
materias[2]
# Out:
# 'ESTADISTICA'

# %%
materias[-1]
# Out:
# 'PROGRAMACION'

# %%
materias[1:4]
# Out:
# ['PROBABILIDAD', 'ESTADISTICA', 'PROGRAMACION']

# %%
materias[0][-1]
# Out:
# 'O'

# %% [markdown]
# **Número de elementos**
# Por medio de la función `len` podemos conocer el número de elementos dentro de una lista.

# %% [markdown]
# **Suma de elementos**
# Otra de las funciones incluidas en Python es `sum`, sobre la cuál podemos sumar todos los elementos de la lista

# %%
sum([1, 2, 3, 4, 5])
sum([90.515,14.681,367.68741])
# Out:
# 472.88341

# %%
sum(["str1", "str2"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-0198b3336473> in <module>
# ----> 1 sum(["str1", "str2"])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
mi_lista = [90.515,14.681,367.68741,24.63]

# Nos regresa una nueva lista ordenada
sorted(mi_lista)
# Out:
# [14.681, 24.63, 90.515, 367.68741]

# %%
sorted(mi_lista, reverse=True)
# Out:
# [367.68741, 90.515, 24.63, 14.681]

# %% [markdown]
# ## Índices
# A diferencia de un `str`, un `list` nos permite obtener, asignar, reemplazar y eliminar valores dentro de una lista.

# %%
# Los strings son inmutables
mi_string = "Hola mundo!"
mi_string[-1] = "?"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-fe263a953a92> in <module>
#       1 # Los strings son inmutables
#       2 mi_string = "Hola mundo!"
# ----> 3 mi_string[-1] = "?"
#
# TypeError: 'str' object does not support item assignment

# %%
print(materias)
# Out:
# ['CALCULO', 'PROBABILIDAD', 'ESTADISTICA', 'PROGRAMACION']

# %%
materias[0] = "ALGEBRA"
print(materias)
# Out:
# ['ALGEBRA', 'PROBABILIDAD', 'ESTADISTICA', 'PROGRAMACION']

# %%
# Eliminar elementos de una lista
materias[1:3] = []
print(materias)
# Out:
# ['ALGEBRA', 'PROGRAMACION']

# %% [markdown]
# ### Estructura:
# Las listas pueden agrupar cualquier tipo de objeto

# %%
e = 2.7183
mi_lista = [e, "pi", ["alpha", "beta", "gamma"], True, False]
print(mi_lista)
# Out:
# [2.7183, 'pi', ['alpha', 'beta', 'gamma'], True, False]

# %%
# Acceder a alpha
mi_lista[2][0]
# Out:
# 'alpha'

# %%
mi_lista_2 = [e, "pi", [[1,2,3], "beta", "gamma"], True, False]

# Acceder al numero 2
mi_lista_2[2][0][1]
# Out:
# 2

# %% [markdown]
# ### Concatenar dos listas

# %%
[1,2,3] + [4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Copiar dos listas

# %% [markdown]
# Cada elemento en python lo identifica un único `id`.

# %%
id(materias)
# Out:
# 2997859767936

# %%
mi_lista = materias

id(mi_lista)
# Out:
# 2997859767936

# %%
print(mi_lista)
print(materias)
# Out:
# ['ALGEBRA', 'PROGRAMACION']
# ['ALGEBRA', 'PROGRAMACION']

# %%
mi_lista[0] = "CALCULO"

# %%
print(mi_lista)
print(materias)
# Out:
# ['CALCULO', 'PROGRAMACION']
# ['CALCULO', 'PROGRAMACION']

# %% [markdown]
# para copiar una lista se indexa sobre todos los elementos de la lista

# %%
materias_2 = materias.copy()
print(materias)
print(id(materias_2))
# Out:
# ['CALCULO', 'PROGRAMACION']
# 2997859777280

# %%
print(id(materias))
print(id(materias[:]))
# Out:
# 2997859767936
# 2997861140032

# %% [markdown]
# ### Métodos de un `list`
# Al igual que los strings, las listas contienen métodos (funciones definidas para una sola clase)

# %%
# Agregar elementos al final
materias.append("PROBABILIDAD")
print(materias)
# Out:
# ['CALCULO', 'PROGRAMACION', 'PROBABILIDAD']

# %%
materias.append("ALGEBRA")
print(materias)
# Out:
# ['CALCULO', 'PROGRAMACION', 'PROBABILIDAD', 'ALGEBRA']

# %%
# Agegar un elemento en una posicion especifica
materias.insert(0, "FINANZAS")
print(materias)
# Out:
# ['FINANZAS', 'CALCULO', 'PROGRAMACION', 'PROBABILIDAD', 'ALGEBRA']

# %%
# Insertar materia despues de calculo
materias.insert(2, "ESTADISTICA")
print(materias)
# Out:
# ['FINANZAS', 'CALCULO', 'ESTADISTICA', 'PROGRAMACION', 'PROBABILIDAD', 'ALGEBRA']

# %%
# Es similar al .find de los strings
materias.index("PROGRAMACION")
# Out:
# 3

# %%
# Eliminar un elemento de la lista y regresarte ese elemento
materia_reprobada = materias.pop(5)
print(materias)
print(materia_reprobada)
# Out:
# ['FINANZAS', 'CALCULO', 'ESTADISTICA', 'PROGRAMACION', 'PROBABILIDAD']
# ALGEBRA

# %%
materias.sort()
materias
# Out:
# ['CALCULO', 'ESTADISTICA', 'FINANZAS', 'PROBABILIDAD', 'PROGRAMACION']

# %% [markdown]
# ### `str`s y `list`s
# Los strings contienen métodos cuyos resultados o argumentos contienen listas

# %%
# Convertir de un string a una lista
linea_csv = "CEMEX,WALMART,BBVA,COSTCO,APPLE"
lista_split = linea_csv.split(",")
print(lista_split)
# Out:
# ['CEMEX', 'WALMART', 'BBVA', 'COSTCO', 'APPLE']

# %%
# Convertir de una lista a un string
"|".join(lista_split)
# Out:
# 'CEMEX|WALMART|BBVA|COSTCO|APPLE'

# %% [markdown]
# <h2 style="color:#B22222"> Ejercicios </h2>
#
# 1. Considera la lista `numeros0` y cálcula el valor promedio
# ```python
# numeros0 = [1, 1, 2, 3, 5, 8, 13]
# ```
# 2. Considera la lista `numeros1` y cálcula la suma del primer, último y el número en medio de la lista (**nota:** El número de elementos en la lista es impar)
# ```python
# numeros1 = [0, 7, 20, 11, 1, 17, 4, 13, 9, 0, 12, 18, 5, 10, 8, 0, 10, 6, 19, 19, 10, 9, 4, 4, 18, 18, 0]
# ```
# 1. Considerando `list1`, reemplaza cada elemento `"a"` por `"*"`.
# ```python
# list1 = ["a", "b", "a", "d", "a", "a", "c"]
# ```

# %%
# Ejercicio 1
numeros0 = [1, 1, 2, 3, 5, 8, 13]
sum(numeros0) / len(numeros0)
# Out:
# 4.714285714285714

# %%
# Ejercicio 2
numeros1 = [0, 7, 20, 11, 1, 17, 4, 13, 9, 0, 12, 18, 5, 10, 8, 0, 10, 6, 19, 19, 10, 9, 4, 4, 18, 18, 0]
numeros1[0] + numeros1[-1] + numeros1[int(len(numeros1)/2)]
# Out:
# 10

# %%
# Ejercicio 3
list1 = ["a", "b", "a", "d", "a", "a", "c"]
mi_string = ",".join(list1)
mi_string = mi_string.replace("a", "*")
mi_string.split(",")
# Out:
# ['*', 'b', '*', 'd', '*', '*', 'c']

# %% [markdown]
# # (Tuples)
# Arreglo ordenado e inmutable de elementos

# %%
materias = ("CALCULO", "FINANZAS", "ALGEBRA")
type(materias)
# Out:
# tuple

# %% [markdown]
# ### Propiedades de un *tuple*:

# %%
materias
# Out:
# ('CALCULO', 'FINANZAS', 'ALGEBRA')

# %%
materias[0]
# Out:
# 'CALCULO'

# %%
materias[0] = "PROBABILIDAD"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-cbb66c4bd2a7> in <module>
# ----> 1 materias[0] = "PROBABILIDAD"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### ¿Por qué usar un *tuple*?

# %% [markdown]
# ### Ejemplo: Un tuple para asignar valores

# %%
strikes_opciones = (90, 100, 100)

# %%
strike_1, strike_2, strike_3 = strikes_opciones

# %%
print(strike_1)
print(strike_2)
print(strike_3)
# Out:
# 90
# 100
# 100

# %%
strike_1, strike_2, strike_3
# Out:
# (90, 100, 100)

# %%
# Tambien sirve para intercambiar valores de dos variable
x = 100
y = 5

# %%
temp = x
x = y
y = temp
print('x:',x)
print('y:',y)
# Out:
# x: 5
# y: 100

# %%
x = 100
y = 5

(x, y) = (y, x)

print('x:',x)
print('y:',y)
# Out:
# x: 5
# y: 100

# %% [markdown]
# # {Diccionaries: Values}
# Hasta el momento hemos visto colecciones de elementos ordenados por un único índice número y numerado. Ahora veremos otra clase de objetos, los **diccionarios**, los cuáles son listas asociativas indexadas por llave; no por orden.
#
# La sintáxis de un diccionario:
# ```python
# {llave1: valor1,
#  llave2: valor2,
#  ...
#  llaven: valorn}
# ```

# %% [markdown]
# ### ¿Por qué usaríamos un diccionario y no una lista?:
# Un diccionario de personas

# %%
nombres = ["ANA", "BETO", "JOSE"]
calificacion = [10, 9, 7]
curso = ["MATEMATICAS", "FINANZAS", "FINANZAS"]

# %%
idx = 0
print(f'El alumno: {nombres[idx]}, sacó: {calificacion[idx]}, en la materia: {curso[idx]}')
idx = 1
print(f'El alumno: {nombres[idx]}, sacó: {calificacion[idx]}, en la materia: {curso[idx]}')
idx = 2
print(f'El alumno: {nombres[idx]}, sacó: {calificacion[idx]}, en la materia: {curso[idx]}')
# Out:
# El alumno: ANA, sacó: 10, en la materia: MATEMATICAS
# El alumno: BETO, sacó: 9, en la materia: FINANZAS
# El alumno: JOSE, sacó: 7, en la materia: FINANZAS

# %%
alumnos = {"ANA": [10, "MATEMATICAS"], "BETO": [9, "FINANZAS"], "JOSE": [7, "FINANZAS"]}

# %%
print("ANA:", alumnos["ANA"])
print("BETO:", alumnos["BETO"])
print("JOSE:", alumnos["JOSE"])
# Out:
# ANA: [10, 'MATEMATICAS']
# BETO: [9, 'FINANZAS']
# JOSE: [7, 'FINANZAS']

# %%
print("PATRICIO:", alumnos["PATRICIO"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-5dac559c1e78> in <module>
# ----> 1 print("PATRICIO:", alumnos["PATRICIO"])
#
# KeyError: 'PATRICIO'

# %%
# Las llaves deben ser unicas e inmutables (no es recomendable utilizar flotantes)
# Los valores SÍ pueden ser cualquier tipo de objeto
mi_dict = {1: "uno", 2: ["d","o","s"], 3: "tres"}

# %%
# No podemos tener llaves duplicadas
mi_dict = {1: "uno", 2: "dos", 3: "tres", 3: "tres!"}
mi_dict
# Out:
# {1: 'uno', 2: 'dos', 3: 'tres!'}

# %% [markdown]
# ### Métodos dentro de un diccionario

# %%
# Nos va a regresar las llaves del diccionario
alumnos.keys()
# Out:
# dict_keys(['ANA', 'BETO', 'JOSE'])

# %%
# Nos va a regresar los valores del diccionario
alumnos.values()
# Out:
# dict_values([[10, 'MATEMATICAS'], [9, 'FINANZAS'], [7, 'FINANZAS']])

# %%
# Nos va a regresar una lista de tuplas con dos elementos. El primer elemento es la llave y el segundo el valor -> 
# (llave, valor)
alumnos.items()
# Out:
# dict_items([('ANA', [10, 'MATEMATICAS']), ('BETO', [9, 'FINANZAS']), ('JOSE', [7, 'FINANZAS'])])

# %%
print(alumnos)
# Out:
# {'ANA': [10, 'MATEMATICAS'], 'BETO': [9, 'FINANZAS'], 'JOSE': [7, 'FINANZAS']}

# %%
print(alumnos["BETO"])
# Out:
# [9, 'FINANZAS']

# %%
print('Primer elemento de la lista:', list(alumnos.items())[0])
print('Segundo elemento de la lista:', list(alumnos.items())[1])
print('Tercer elemento de la lista:', list(alumnos.items())[2])
# Out:
# Primer elemento de la lista: ('ANA', [10, 'MATEMATICAS'])
# Segundo elemento de la lista: ('BETO', [9, 'FINANZAS'])
# Tercer elemento de la lista: ('JOSE', [7, 'FINANZAS'])

# %% [markdown]
# ## {Sets}
#
# Un `set` (conjunto) es una colección no ordenada de valores únicos. Para dos conjuntos `A`, `B` y valores `a` dentro de `A` y `b` dentro de `B`, se cumplen con las siguientes características
# * `A & B` (Intersección): Elementos en `A` y en `B`
# * `A | B` (Unión): Elementos en `A` o en `B`
# * `A - B` (Diferencia): Elementos en `A` no presentes en `B`
# * `A ^ B` (Diferencia Simétrica): Elementos en cualquiera de los conjuntos `A` o `B`, mas no en los dos.
# * `A <= B` (Subconjunto): Prueba si todos los elementos en `A` se encuentran dentro de `B`
# * `A >= B` (Superconjunto): Prueba si todos los elementos en `B` se encuentran dentro de `A`

# %%
# No tienen que ser valores unicos
mi_lista = ["a", "a", "a", "a"]
mi_lista
# Out:
# ['a', 'a', 'a', 'a']

# %%
vocales = {"a", "e", "i", "o", "u"}
type(vocales)
# Out:
# set

# %%
print(vocales)
# Out:
# {'u', 'a', 'i', 'e', 'o'}

# %%
palabra = {"c", "a", "r", "r", "o"}

# %%
#Solo valores unicos
print(palabra)
# Out:
# {'c', 'a', 'o', 'r'}

# %%
palabra & vocales
# Out:
# {'a', 'o'}

# %%
palabra | vocales
# Out:
# {'a', 'c', 'e', 'i', 'o', 'r', 'u'}

# %%
palabra - vocales
# Out:
# {'c', 'r'}

# %%
vocales - palabra
# Out:
# {'e', 'i', 'u'}

# %%
vocales ^ palabra
# Out:
# {'c', 'e', 'i', 'r', 'u'}

# %% [markdown]
# <h2 style="color:#B22222"> Ejercicio </h2>
#
# 1. Dado el diccionario `vocales`, accede al primer elemento dentro de la llave `"minusculas"`
# ```python
# vocales = {
#     "mayusculas": ['A', 'E', 'I', 'O', 'U'],
#     "minusculas": ['a', 'e', 'i', 'o', 'u']
# }
# ```
# 2. Modifica el diccionario `alumnos` de tal manera que cada llave del diccionario sea el nombre del estudiante y el valor un diccionario adicional con las llaves `"edad"`, `"color_favorito"`, `"carrera"`, asignados a sus valores correspondientes.
# 3. ¿Cuál es la longitud del set `{'q', 'u', 'e', 'u', 'e'}`? Explica.
# 4. Considerando los conjuntos `investor1`, `investor2` e `investor3`
#     * Encuentra todas las acciones que `investor1`, `investor2`, `investor3` e `investor4` tienen en conjunto
#     * Encuentra las acciones que `investor1`, `investor3` e `investor4` tienen en común
#
# ```python
# investor1 = {'HOTEL', 'CHDRAUI', 'ALPEK', 'VISTA', 'MFRISCO', 'AHMSA', 'LAB', 'SPORT', 'SAVIA', 'LASEG'}
# investor2 = {'CMOCTEZ', 'BEVIDES', 'OMA', 'GNP', 'AGRIEXP', 'SPORT', 'TRAXION', 'GENTERA', 'COLLADO', 'LAMOSA'}
# investor3 = {'FEMSA', 'ALSEA', 'BIMBO', 'ELEMENT', 'FINAMEX', 'GCC', 'VISTA', 'GEO', 'IENOVA', 'OMA', 'CADU', 'ANB', 'AUTLAN', 'GICSA', 'GFNORTE', 'IDEAL', 'MEXCHEM', 'ELEKTRA', 'SITES', 'CABLE'}
# investor4 = {'GENTERA', 'BOLSA', 'VISTA', 'TEAK', 'ACCELSA', 'CUERVO', 'TEKCHEM', 'QBINDUS', 'MEDICA', 'URBI', 'CIE', 'NEMAK', 'KIMBER', 'GPH', 'GMD', 'ACTINVR', 'GAP', 'JAVER', 'INGEAL', 'ARA'}
# ```

# %%
# Ejercicio 1
vocales = {
 "mayusculas": ['A', 'E', 'I', 'O', 'U'],
 "minusculas": ['a', 'e', 'i', 'o', 'u']
}

# %%
vocales["minusculas"][0]
# Out:
# 'a'

# %%
# Ejercicio 2
alumnos = {"ANA": {"edad": 24, "color_favorito": "rojo","carrera": "ACTUARIA"},
           "BETO": {"edad": 21, "color_favorito": "amarillo","carrera": "INGENIERIA"},
           "JOSE": {"edad": 22, "color_favorito": "verde","carrera": "COMPUTACION"}}

# %%
print(alumnos)
# Out:
# {'ANA': {'edad': 24, 'color_favorito': 'rojo', 'carrera': 'ACTUARIA'}, 'BETO': {'edad': 21, 'color_favorito': 'amarillo', 'carrera': 'INGENIERIA'}, 'JOSE': {'edad': 22, 'color_favorito': 'verde', 'carrera': 'COMPUTACION'}}

# %%
print(alumnos["ANA"])
# Out:
# {'edad': 24, 'color_favorito': 'rojo', 'carrera': 'ACTUARIA'}

# %%
print(alumnos["ANA"]["edad"])
# Out:
# 24

# %%
print(alumnos["JOSE"]["edad"])
# Out:
# 22

# %%
# Ejercicio 3
len({'q', 'u', 'e', 'u', 'e'})
# Out:
# 3

# %%
# Ejercicio 4
investor1 = {'HOTEL', 'CHDRAUI', 'ALPEK', 'VISTA', 'MFRISCO', 'AHMSA', 'LAB', 'SPORT', 'SAVIA', 'LASEG'}
investor2 = {'CMOCTEZ', 'BEVIDES', 'OMA', 'GNP', 'AGRIEXP', 'SPORT', 'TRAXION', 'GENTERA', 'COLLADO', 'LAMOSA'}
investor3 = {'FEMSA', 'ALSEA', 'BIMBO', 'ELEMENT', 'FINAMEX', 'GCC', 'VISTA', 'GEO', 'IENOVA', 'OMA', 'CADU', 'ANB', 'AUTLAN', 'GICSA', 'GFNORTE', 'IDEAL', 'MEXCHEM', 'ELEKTRA', 'SITES', 'CABLE'}
investor4 = {'GENTERA', 'BOLSA', 'VISTA', 'TEAK', 'ACCELSA', 'CUERVO', 'TEKCHEM', 'QBINDUS', 'MEDICA', 'URBI', 'CIE', 'NEMAK', 'KIMBER', 'GPH', 'GMD', 'ACTINVR', 'GAP', 'JAVER', 'INGEAL', 'ARA'}

# %%
todas_las_acciones = investor1 | investor2 | investor3 | investor4
print(todas_las_acciones)
# Out:
# {'MEXCHEM', 'KIMBER', 'AUTLAN', 'CADU', 'VISTA', 'LASEG', 'ALPEK', 'AHMSA', 'GICSA', 'ANB', 'CIE', 'BIMBO', 'LAB', 'ELEKTRA', 'FINAMEX', 'CUERVO', 'SITES', 'LAMOSA', 'SAVIA', 'INGEAL', 'MFRISCO', 'MEDICA', 'TRAXION', 'IDEAL', 'CABLE', 'GAP', 'HOTEL', 'TEKCHEM', 'BEVIDES', 'GFNORTE', 'GEO', 'TEAK', 'ACTINVR', 'OMA', 'URBI', 'ACCELSA', 'GMD', 'ARA', 'AGRIEXP', 'GPH', 'QBINDUS', 'ELEMENT', 'ALSEA', 'IENOVA', 'SPORT', 'CMOCTEZ', 'CHDRAUI', 'JAVER', 'GNP', 'GCC', 'COLLADO', 'GENTERA', 'BOLSA', 'FEMSA', 'NEMAK'}

# %%
acciones_en_comun = investor1 & investor3 & investor4
print(acciones_en_comun)
# Out:
# {'VISTA'}
